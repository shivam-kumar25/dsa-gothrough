# %% [markdown]
# ################################################
# ################################################
# ################################################
# # Week 1 (PDSA)
# ################################################
# ################################################
# ################################################

# %%
##################################################################
# Timer in python
##################################################################

import time

# Start the timer
start_time = time.time()

#----------------------------- Your code block starts
total = 0
for i in range(1, 100000000):
    total += i
#----------------------------- Your code block ends

# End the timer
end_time = time.time()

# Calculate execution time
execution_time = end_time - start_time

print("Execution time:", execution_time, "seconds")
# Out:
# Execution time: 15.207163095474243 seconds

# %% [markdown]
# #-----------------------------------------
# # PPA Week 1

# %%
# PPA 1

"""
Twin primes are pairs of prime numbers that differ by 2. For example (3, 5), (5, 7), and (11,13) are twin primes.
Write a function Twin_Primes(n, m) where n and m are positive integers and n < m , that returns all unique twin primes between m and n (both inclusive). The function returns a list of tuples and each tuple (a,b) represents one unique twin prime where n <= a < b <= m.
"""


def Is_Prime(k):
    """ just a function to check if a number is prime """
    for num_ in range(2,k):
        if  k % num_ == 0:
            return False
    return True

def Twin_Primes(n,m):
    ################################
    prime_list = []
    for i in range(n,m+1):
        if Is_Prime(i) == True:
            prime_list.append(i)

    ################################
    result = []
    for i in range(0,len(prime_list)-1):
        if (prime_list[i+1]-prime_list[i]) == 2 :
            result.append((prime_list[i],prime_list[i+1]))

    return result



print(Twin_Primes(5,50))
# Out:
# [(5, 7), (11, 13), (17, 19), (29, 31), (41, 43)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# PPA 2

class Triangle:

    def __init__(self, a , b , c):
        self.a=a
        self.b=b
        self.c=c

    #### Function to chek if a traingle is valid
    def Is_valid(self):
        if (self.a +self.b >self.c ) and (self.b +self.c >self.a) and (self.a +self.c >self.b):
            return "Valid"
        else:
            return "Invalid"

    #### Function to chk for the type of triangle accoding to the sides
    def Side_Classification(self):
        if self.Is_valid() == "Valid":
            if self.a == self.b == self.c :
                return "Equilateral"
            elif (self.a == self.b != self.c) or (self.a == self.c != self.b) or (self.a != self.b == self.c) :
                return "Isosceles"
            elif self.a != self.b != self.c :
                return "Scalene"

        else:
            return "Invalid"

    ### Function to chk the type of the trangle according to angles using pythagoras theorme
    def Angle_Classification(self):
        if self.Is_valid() == "Valid" :
            smallest_side , middle_side , biggest_side = sorted([self.a , self.b , self.c])

            if ( (smallest_side)**2 + (middle_side)**2 == (biggest_side)**2 )  :
                return "Right"

            elif ( (smallest_side)**2 + (middle_side)**2 >= (biggest_side)**2 ) :
                return "Acute"

            elif ( (smallest_side)**2 + (middle_side)**2 <= (biggest_side)**2 )  :
                return "Obtuse"

        else:
            return "Invalid"

    ### Function to get the area of the tiangle
    def Area(self):
        if self.Is_valid() == "Valid" :
            s = ( self.a + self.b + self.c ) / 2
            area = ( s * (s-self.a) * (s-self.b) * (s-self.c) ) ** 0.5
            return area

        else:
            return "Invalid"


a,b,c = 2,2,3
T=Triangle(a,b,c)
print(T.Is_valid())
print(T.Side_Classification())
print(T.Angle_Classification())
print(T.Area())
# Out:
# Valid
# Isosceles
# Obtuse
# 1.984313483298443

# %% [markdown]
# #-----------------------------------------
# # GRPA Week 1

# %%
# GRPA 1

# Write a function find_Min_Difference(L, P) that accepts a list L of integers and P (positive integer) where the size of L is greater than P. The task is to pick P different elements from the list L, where the difference between the maximum value and the minimum value in selected elements is minimum compared to other differences in possible subset of p elements. The function returns this minimum difference value.
# Note - The list can contain more than one subset of p elements that have the same minimum difference value.
# Example
# Let L = [3, 4, 1, 9, 56, 7, 9, 12, 13] and P = 5
# If we see the following two subsets of 5 elements from L
# [3, 4, 7, 9, 9] or [7, 9, 9, 12, 13]
# Here, the difference between the maximum value and the minimum value in both subset is 9 - 3 = 6 or 13 - 7 = 6 which is minimum. So the output will be 6.
# Sample Input
# [3, 4, 1, 9, 56, 7, 9, 12]
# 5
# Output
# 6


def find_Min_Difference ( L , P ):
    """
    Function to find the minimum difference between the maximum and minimun element in a subset of P element chosen form list L.

    Parameters:
    L (list): A list of intergers.
    P (int): Number of element to pick from the list.

    Returns:
    int: Minimum possible difference between the max and min element in a subset of P elemetns.

    """
    if P<=0 or P>len(L):
        return 0   # invalid case

    sorted_lsit = sorted(L)

    list_ = []
    for i in range(0 , len(L) - P + 1):
        list_.append(sorted_lsit[i : i+P])

    difference_list = []
    for mini_lst in list_ :
        difference_list.append(max(mini_lst)-min(mini_lst))

    return min(difference_list)




L = [3, 4, 1, 9, 56, 7, 9, 12, 13]
P = 5
print(find_Min_Difference(L,P))
# Out:
# 6

# %% [markdown]
# ![Screenshot 2025-03-21 143807.png](data:image/png;base64,...)

# %%
# GRPA 2


def is_prime(num):
    """
    Function to check if a number is prime.
    """
    if num < 2 :
        return False
    for i in range( 2 , (int(num**0.5)+1) ) :
        if num % i == 0 :
            return False
    return True


def Goldbach(n):
    """
    Function to  find all possible pair of prime numbers (a,b) such that:
    - Their sum is equal to the given even number n.
    - The order is maintained such that  a<=b to avoid dublicate pairs.

    Parameters:
    n (int): The even number of which we need to find prime number pairs.

    Returns:
    list: A list of tuples where each tuple (a,b) represent a valid prime number.
    """
    prime_list = []
    for i in range(2,n):
        if is_prime(i) == True :
            prime_list.append(i)

    result_ = []
    for a in prime_list:
        for b in prime_list:
            if (a+b) == n :
                result_.append(( min(a,b) , max(a,b) ))

    return list(set(result_))




n=int(input())
print(sorted(Goldbach(n)))
# Out:
# 26
# [(3, 23), (7, 19), (13, 13)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# GRPA 3

def odd_one(L):
    """
    Function to determine the data type of the odd one out in a given list.
    """

    # Create an empty dictionary {} to count the occurance of each data type.
    type_counts_ = {}

    for item in L:
        item_type = (type(item)).__name__ # Get the type of the element as a string (e.g., "int", "float", "str", "bool")

        # Update the count of the  detected type in the dictionary
        if item_type in type_counts_ :
            type_counts_[item_type] += 1  # If the type already exists in dictionary, increment its count
        else:
            type_counts_[item_type] = 1   # If its the first time encountering this type, set its count to 1


    # Step 4: Identify the data type with the least occurance in the dictionary.
    for key_ , value_ in type_counts_.items():
        if value_ == 1 :  # If a type appears only once, its the odd one out.
            return key_   # Return the name of the odd element's data type as a string




print(odd_one([2,13,16,4.5]))
# Out:
# float

# %%
# GRPA 3
def odd_one(L):
    """
    Function to determine the data type of the odd one out in a given list.
    """
    int_count = 0
    float_count = 0
    str_count = 0
    bool_count = 0

    for i in L:
        if type(i) == int:
            int_count += 1
        elif type(i) == str:
            str_count +=1
        elif type(i) == bool:
            bool_count += 1
        elif type(i) == float:
            float_count +=1


    if int_count == 1:
        return "int"
    elif float_count == 1:
        return "float"
    elif str_count == 1:
        return "str"
    elif bool_count == 1:
        return "bool"
    else:
        return None



print(odd_one([2,1,2,16,4.5]))
# Out:
# float
